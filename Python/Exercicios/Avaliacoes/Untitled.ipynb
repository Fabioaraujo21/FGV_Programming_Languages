# %%
#letra a da primeira
def diciomalandro(string):
    dicio={}
    string=string.upper()
    stringao=string.split()
    for palavrinha in stringao:
        if palavrinha in dicio:
            dicio[palavrinha]+=1
        else:
            dicio[palavrinha]=1
    return dicio
diciomalandro(texto)
# Out:
# {'FELIZES;': 1,
#  'MESTRES,': 1,
#  'CHEGADA': 2,
#  'OFFERECEU': 2,
#  'CHALE': 1,
#  'MENDIGO.': 1,
#  'WITH': 48,
#  'DESTE:': 1,
#  'BRAZA,': 1,
#  'FAMILIARMENTE': 1,
#  'LER': 9,
#  'TALVEZ': 31,
#  'SABBADO!': 2,
#  'THERAPEUTICA.': 1,
#  'CORAÇÃO?': 1,
#  'CONTOS': 2,
#  'PERGUNTAVA:': 1,
#  'EMENDAL-O.': 1,
#  'ACCRESCENTAVA.': 1,
#  '--PERDER': 1,
#  'VÁS': 4,
#  'PRECISÁRA': 1,
#  '_COME': 1,
#  'NOTARAM': 1,
#  'MORAVA,': 1,
#  'ENCONTROS': 1,
#  '--DELICIOSISSIMA!': 1,
#  'ESQUIVOS,': 1,
#  'FREIRE,': 1,
#  'MINTO;': 1,
#  'TELEGRAPHICO?': 1,
#  'APPRENDER': 7,
#  'LOPES...': 1,
#  'TURBULENTO,': 1,
#  'ESBELTO,': 1,
#  'BANDÓS,': 1,
#  'LEPRA': 1,
#  'CASANDO-SE.': 1,
#  'FOLHEAR': 2,
#  'CHACARA;': 1,
#  'VAGALUMES,': 1,
#  'ADDRESSES.': 1,
#  'EXPERIMENTAR': 1,
#  'ESTENDENDO': 2,
#  'OUVIDOS,': 2,
#  'ANDADO': 1,
#  'LUTAM': 2,
#  'PRIMEIRAS,': 2,
#  'INQUIETO.': 1,
#  'INVENTARAM.»': 1,
#  'BILHETES': 2,
#  'LIVRO;': 1,
#  'ARIOSTO': 1,
#  'APALPAR-ME,': 1,
#  'SANTAS': 1,
#  'TOMÁMOS': 1,
#  'DEMOS': 1,
#  'VONTADE,': 4,
#  'ECCLESIASTICO': 1,
#  'DEBATES.': 1,
#  'TOTAL,': 3,
#  'VULGATA,': 1,
#  'CEDESSE': 1,
#  'RUMORES;': 1,
#  'DEI-OS': 1,
#  'PRENDENDO': 1,
#  'GABINETE;': 1,
#  'DIGA-ME.»': 1,
#  '«BOA-VIDA»;': 1,
#  'RISCA': 1,
#  'APRECIAVEL,': 1,
#  'COMENDO': 1,
#  'POSTUMA,': 1,
#  'DISTRIBUTING,': 1,
#  'CXXXII': 2,
#  'PEDIRIA': 2,
#  'ESTAVA.': 3,
#  'ORADOR,': 1,
#  'INDAGAR;': 1,
#  'COUBESSE': 1,
#  '--ALEMBRA,': 1,
#  'FINAS,': 2,
#  'TORNARAM,': 1,
#  'BARBEIRO,': 2,
#  'CASO....': 1,
#  'EXCLAMEI:': 1,
#  'LAPA;': 1,
#  'DORMISSE.': 1,
#  'DESCERAM-ME': 1,
#  'ADIEMOS': 2,
#  'VISINHOS?': 1,
#  'OUSASSE': 1,
#  'CALÇAS': 5,
#  'ENTENDER,': 1,
#  'DIVIDIA-SE': 1,
#  'QUERES.': 1,
#  'REPARAR': 1,
#  'ESFORÇO': 2,
#  'CONCORDO;': 1,
#  'VALHA': 1,
#  'BOCHECHAS,': 1,
#  'ESTRELLAS,': 2,
#  'ESSENCE._': 2,
#  'ORDENADO': 1,
#  'BOLIR': 1,
#  'PASSARO': 1,
#  'INTELLECTUAES,': 1,
#  'PROMESSA.': 4,
#  'MOI,': 1,
#  'FUTURO,': 2,
#  'DEDUCTIBLE': 1,
#  'ABORRECIDA,': 1,
#  'ACÇÕES': 4,
#  '(ERA': 1,
#  "D'ISTO": 1,
#  'TRADEMARK.': 3,
#  'CHORAES,': 1,
#  'DISPUZ-ME': 1,
#  'NOVA': 13,
#  'ESQUEÇO': 1,
#  'ESCRIPTOS.': 1,
#  'CALAR': 1,
#  'NENHUMA': 11,
#  'SANTOS': 4,
#  '«SIM,': 1,
#  'INQUIETA,': 1,
#  'UP,': 1,
#  'ESPANCARAM': 1,
#  'AFASTASSEM': 1,
#  'DEIXEMOS': 2,
#  'COUSA:': 1,
#  'NOBREMENTE': 1,
#  'VISTE': 3,
#  'INQUIETOS,': 1,
#  'FÉRIAS!': 1,
#  'U.S.': 7,
#  'TAES;': 2,
#  'MEXENDO': 1,
#  'SAUDADE.': 1,
#  'PAY': 1,
#  'SEMPRE,': 4,
#  'PREÇO': 2,
#  'SAIDO': 2,
#  '_GOUACHE_,': 1,
#  'NOITE?': 1,
#  'ARGUMENTOS': 1,
#  'CRESCIDOS,': 1,
#  'INVENTAVA': 1,
#  'SANTO;': 1,
#  'SALTEI': 1,
#  'LOGO?': 1,
#  'CORRIGIA,': 1,
#  'DIZIAMOS.': 1,
#  'CURTA.': 4,
#  'APALPAVA-LHE': 1,
#  'DESEMPREGADOS.': 1,
#  'ABRIU': 5,
#  'DIR-ME-HIA,': 1,
#  'APPARENTEMENTE': 1,
#  'DIGITAL': 2,
#  'XXIV': 2,
#  'FLUIDO': 2,
#  'INSCRIPÇÃO,': 1,
#  'PROFERI': 2,
#  'DESPEDIR-SE': 4,
#  'TOCAVA...': 1,
#  'TOSSE?': 1,
#  'PREFERIU': 1,
#  'TRANCAS.': 1,
#  'DISCLAIM': 1,
#  'SOLTAR': 1,
#  'ARRANJAVAMOS': 2,
#  'AGITADO.': 1,
#  'PRENDIA': 2,
#  'PROFERI-AS': 1,
#  'ILLUMINAR-ME': 1,
#  'ESPANTAR': 1,
#  'COLORIDO': 1,
#  'PEGAM': 3,
#  'PÓ': 1,
#  'PECCADOS.': 1,
#  '--PEDIU': 1,
#  'IMPORTARÁ': 1,
#  'LEPRA.': 2,
#  'ANIMO.': 1,
#  'MORTE.': 6,
#  'PRESTES': 1,
#  'NAMORO...»': 2,
#  'MEUS;': 3,
#  'POUSAVA': 1,
#  'PARCELLA': 1,
#  'FEIA;': 2,
#  'AMEAÇAS.': 1,
#  'COMPANHEIROS': 3,
#  'PENTEAR.': 1,
#  'CUIDARAM': 1,
#  'URGIA,': 1,
#  'ESCREVEL-A;': 1,
#  'CHAMAVA-ME': 3,
#  'INTERRUPÇÃO': 1,
#  'DEIXE': 8,
#  '--CREIO': 2,
#  'REPETI-AS': 2,
#  'MÃE»': 1,
#  'RESPONDI.': 1,
#  '--JUSTAMENTE.': 1,
#  'BRILHARAM,': 1,
#  'MAIS,': 18,
#  'SER?': 3,
#  'CONVICÇÃO': 2,
#  'ESCUTAVAMOS': 1,
#  'ORELHAS': 1,
#  'PENSANDO.': 1,
#  'AO': 371,
#  'LACRIMOSA.': 1,
#  'ANTERIORES?': 1,
#  'DIRECÇÃO': 1,
#  'PESQUIZA': 1,
#  'SOCEGAR,': 1,
#  'SOCEGADO,': 2,
#  'CHEIRAVAM': 1,
#  'VEDES': 1,
#  'PRINCIPAES': 1,
#  '--ELLE': 2,
#  'RECOLHI': 1,
#  'CARTORIO': 2,
#  'ZANGAVA-SE.': 1,
#  'ADVERSA,': 1,
#  'ANDADO,': 1,
#  'SAIU.': 1,
#  'LIBRAS': 7,
#  'PEGUEI': 9,
#  'CENSUROU': 1,
#  'EXAMINAR...': 1,
#  'ITALIA': 1,
#  'COITADA!»': 1,
#  'CLARÃO,': 1,
#  'DESCOBRIU': 1,
#  'SEGURO,': 1,
#  'INSISTE,': 1,
#  'TRECHOSINHO': 1,
#  'MEDIANTE': 3,
#  'VONTADE': 19,
#  'PONTE': 1,
#  'ACCRESCE': 1,
#  'DOENTE': 3,
#  'PARTES?': 1,
#  'LIMPOS,': 1,
#  'EXPLICAR....': 1,
#  'FITAR': 2,
#  'CONSIDERANDO': 1,
#  'COMPRIMARIAS,': 1,
#  'PROVAVA;': 1,
#  'VISIT:': 1,
#  'MARCHETADO': 1,
#  'EXTRANHO,': 1,
#  'ESTUDANTE,': 1,
#  'OUVI.': 1,
#  'LENTES,': 2,
#  'MASCATE': 1,
#  'HAVERÁ': 3,
#  'CALOR': 8,
#  'DIMENSÕES': 2,
#  'QUARTO;': 1,
#  'QUANTIA': 2,
#  'GLORIAS': 1,
#  'DIUTURNA,': 1,
#  'SOCIEDADE.': 1,
#  'MAMÃE!': 3,
#  'OCCUPAR': 1,
#  'DIZENDO-ME': 2,
#  'DEFEITO': 1,
#  'DAMAGE': 1,
#  'LXIX': 2,
#  'TUDO,--MAS': 1,
#  'FIM.': 8,
#  'NAQUELLA': 14,
#  'PROMESSA...': 1,
#  'DOENÇA,': 3,
#  'CONTEMPLAM,': 1,
#  'PRINCIPALMENTE': 4,
#  'FESTEJAR': 1,
#  'RECEBEM': 2,
#  'DESVANECIMENTO': 3,
#  'DESFECHO': 1,
#  'ALLUCINADO;': 1,
#  'JANEIRO,': 2,
#  'TIO,--COUSA': 1,
#  'BELLEZAS,': 1,
#  'ABORRECER.': 1,
#  'MULHERES.': 1,
#  'COMPONDO': 1,
#  'ALUMIADA': 1,
#  'ENCARQUILHAR': 1,
#  'APAIXONAR-SE': 1,
#  'VOLTAS,': 2,
#  'TANTA,': 1,
#  'ANTI-RUSSA,': 1,
#  'PAREDE,': 6,
#  'UNIVERSAL,': 1,
#  '--CONFIEI': 1,
#  'EMPANAVA': 1,
#  'UNIVERSIDADE': 1,
#  'LÁ': 41,
#  'PROMINENTLY': 2,
#  'ARCHITECTO': 1,
#  'ESCARNINHO,': 1,
#  'LARGA': 1,
#  'FIZESSE;': 2,
#  'GORDO,': 1,
#  'ORPHÃO,': 1,
#  'VAE,': 1,
#  'QUATRO,': 1,
#  'SUBLIMES': 2,
#  'BONDADE,': 2,
#  'TOCAVA': 5,
#  'BENGALÃO': 1,
#  'PROTONOTARIO,--ACUDIU': 1,
#  'AMARELLADAS': 1,
#  'TRABALHOS': 1,
#  'CONSTANCIA': 1,
#  '7': 2,
#  'SENTIA-OS': 1,
#  'DIA': 67,
#  'VIER': 2,
#  'OLHARA': 1,
#  'ANJO': 6,
#  '15,': 1,
#  'RIO-GRANDE,': 1,
#  'DISCOVERED': 1,
#  'CIUMES,': 2,
#  'VARAS': 2,
#  'ADVOGADO': 4,
#  'DISFARÇAR': 2,
#  'VERDADEIRA;': 1,
#  'VISTES;': 1,
#  'GAIATO': 1,
#  'CARECIAM,': 1,
#  'CONDISCIPULOS': 1,
#  'LICÇÃO,': 1,
#  'COMBORÇO': 1,
#  '--OLHA': 1,
#  'PRESTA,': 1,
#  'COMPARAÇÃO': 5,
#  'IRMÃOS': 2,
#  'MURMUROU:': 1,
#  'PERALTA': 7,
#  '--ESTIVE': 1,
#  'TOCANDO': 2,
#  'ALLIVIADA': 1,
#  'SUSPEITA,': 1,
#  'NOVAS,': 3,
#  'OUVIA-LHE': 1,
#  'REPENTE,': 4,
#  'IDENTIFY,': 1,
#  'AVANCEI': 1,
#  'HOMEM!': 5,
#  'ACTO,': 2,
#  'EDUCATION': 2,
#  'UNICO!': 1,
#  'GASTADEIRA,': 1,
#  'DEFINIÇÃO': 4,
#  'SOLIDAS.': 1,
#  'LULA': 1,
#  'FADIGA': 2,
#  'LEVE': 3,
#  'DAVAMOS': 1,
#  'ERA': 528,
#  'SIDO': 4,
#  'VIVO,': 3,
#  'FINO': 2,
#  'AMEAÇANDO': 1,
#  'RECOLHENDO': 1,
#  'PARTICULAR:': 1,
#  'BARYTONO': 1,
#  'TODA': 35,
#  'GOSTO': 29,
#  'IMPERADOR.': 1,
#  'ESQUEÇAS': 1,
#  'DIABO,': 2,
#  'GRAÇA.': 5,
#  'SOCIEDADE,': 1,
#  'MATAR.': 2,
#  'APEOU-ME,': 1,
#  'MORAL;': 1,
#  'VIM': 14,
#  'GRAÇA,': 7,
#  'VIRTUDES': 6,
#  'MEXER': 1,
#  '11.': 1,
#  'GROTESCO,': 1,
#  'PROMETTE-ME': 1,
#  'APERTADAS,': 1,
#  'CM': 1,
#  'CHRISTÃS': 1,
#  'ADOLESCENCIA.': 1,
#  'LXXXV': 2,
#  'IMPREVISTA.': 1,
#  'EXECUTA': 1,
#  'LXV': 2,
#  'DEMAIS,': 12,
#  'WARRANTIES': 3,
#  'OLHE;': 1,
#  'SR.': 9,
#  'ESPANTADO;': 1,
#  'ILLUSTRES': 1,
#  '--DIZEM': 1,
#  'CREANCA,': 1,
#  'DESPEDI-ME,': 1,
#  'AJUSTE': 2,
#  'MENTIROSO,': 1,
#  'VERMELHOS;': 1,
#  'LONGA': 5,
#  'RECTO': 1,
#  'SUPPLICOU': 1,
#  'CANÇAR': 1,
#  'DESPEDIR-ME.': 1,
#  'COMMERCIALMENTE': 1,
#  '--POIS': 21,
#  'WORLD': 2,
#  'EXTREMOS': 1,
#  'DRAMAS,': 1,
#  'JAZIA': 2,
#  'TOA?': 1,
#  'CAPITULO;': 1,
#  'HOMEOPATHIA,': 1,
#  'RESIDIR': 1,
#  'PASSADAS,': 1,
#  'DIRECÇÃO.': 1,
#  'PEÇAS': 1,
#  'ACONTECIA?': 1,
#  'CASOS,': 2,
#  'ABOTOADO,': 1,
#  'RAIVA,': 1,
#  'IRRITADO': 1,
#  'PADARIA.': 1,
#  'ÀS': 1,
#  'ESQUECIDO,': 1,
#  'REPENTINA.': 1,
#  'HAJA': 3,
#  'CAPITULOS;': 1,
#  'CASE?': 1,
#  'ATTENÇÃO,': 2,
#  'MATRICULAS,': 1,
#  'VIRTUDES,': 3,
#  'DIGO': 23,
#  'LIBRÉ.': 1,
#  'IRMÃ': 1,
#  'DISFARÇAR,': 1,
#  'BEIRAMOS': 1,
#  'EVANGELHO.': 1,
#  'ABRIRA': 2,
#  'ENFIADOS': 3,
#  'SEPULTURA': 3,
#  'NOME;': 1,
#  '«NÃO': 5,
#  'LEVAVA': 10,
#  'CANÇAVA,': 1,
#  'ENTORNEI,': 1,
#  'FAMILIAS,': 1,
#  'ACUDIRAM': 4,
#  'DISSIPAR': 1,
#  'IMPETOS': 1,
#  'HOMEM?»': 2,
#  'ESPERANÇAS': 6,
#  'JULGAL-A;': 1,
#  'DEZESEIS': 3,
#  'OLHASSE': 1,
#  'EFFUSÃO;': 1,
#  'PROTECTED': 5,
#  'IMMEDIATE': 2,
#  'PAQUETE': 2,
#  '_CALCANTE': 1,
#  'SABÕES': 1,
#  'FORÇA.': 4,
#  'LINDISSIMA,': 1,
#  'ATAVA': 1,
#  'SENHOR,': 16,
#  'FAZENDA': 1,
#  'ESTADO.': 1,
#  'DIFFERENTE.': 2,
#  'PREPARAVA': 1,
#  'ENGOMMADAS,': 1,
#  'TERRIVEIS.': 1,
#  'CXXXV': 2,
#  'DADO': 7,
#  'COMO...': 1,
#  'COINCIDENCIA.': 1,
#  'FORÇA,': 3,
#  'IMPULSO.': 1,
#  'IA': 88,
#  'GONÇALVES': 1,
#  'MULTIPLICAM': 1,
#  'GRACEJANDO,': 1,
#  'DATAVA': 1,
#  'SEMINARIO,': 24,
#  'BELLISSIMAS!': 1,
#  'CONTINUA': 1,
#  'DERAM': 5,
#  'AGULHA': 1,
#  'EXIGIR': 1,
#  'PRIMO': 1,
#  'SUSSURREI': 1,
#  'FALA': 2,
#  'AFFLIGIAM': 1,
#  'RECEIVE': 3,
#  'SUCH': 6,
#  'ISSO,': 9,
#  'ALMA.': 6,
#  'APPROVA': 1,
#  'RITUAL.': 1,
#  'ESPETAVA': 1,
#  'ANTIGOS': 3,
#  'PEDIR-LHE': 4,
#  'ESCURA,': 4,
#  'OFFICIOS': 4,
#  'ESMORECE.': 1,
#  'FIXA;': 1,
#  'ESPERASSE': 3,
#  'SOMMARIA': 1,
#  'RIA-SE': 1,
#  'LÁ.': 8,
#  'FILHO!»': 1,
#  'MÁ.': 2,
#  'PORTÃO': 3,
#  'CHEGUE': 3,
#  'DESCOBRIAM': 1,
#  'CONTESTADO': 1,
#  'SEREI': 3,
#  'AGRADAVEIS.': 1,
#  'CARIDADE,': 2,
#  'ESCREVENDO-ME,': 1,
#  'HUMANAS,': 3,
#  'EXIGIA': 1,
#  'JURA?': 2,
#  'VERÁ;': 1,
#  'NESSAS': 1,
#  '--AQUI': 1,
#  'PERGUNTANDO': 1,
#  'PORTÃO.': 1,
#  'SANTIAGO,': 4,
#  'ALGUMA': 67,
#  'PRESIGANGA,': 1,
#  'QUOQUE,': 1,
#  'II:': 1,
#  'FAZEL-AS': 2,
#  'ESPIRITUAES,': 1,
#  'COMPENSAÇÃO,': 1,
#  'ARDENTE,': 1,
#  'ZANGAREM': 1,
#  'ABALO': 1,
#  'ESTIMEI': 2,
#  'TRAZEM': 1,
#  'PERNAS,': 1,
#  'PARAR.': 1,
#  'TREPADAS': 4,
#  'GRAÇA...': 1,
#  'PRETA,': 1,
#  'LAVAVA': 1,
#  'VIUVAS,': 1,
#  'DESATTENÇÃO': 1,
#  'CAMARAS.»': 1,
#  'CEDE...': 1,
#  'OUVIRIA': 1,
#  'COMPREI-AS,': 1,
#  'LEREM,': 1,
#  'ATLANTICO,': 1,
#  'MEDICINA;': 2,
#  'PREFERIA': 3,
#  'SORTE': 4,
#  'PALAVRAS,': 20,
#  'CEMITERIO,': 6,
#  'METAL': 1,
#  'RALHAVA.': 1,
#  'PUERIL;': 1,
#  'PERFIS': 1,
#  'CAIDOS': 1,
#  'ENTROU-ME': 1,
#  'DEIXAL-A,': 1,
#  'ARRENEGAR': 2,
#  'FALASSE,': 1,
#  'AJOELHAVAM': 1,
#  'BREVIDADE': 1,
#  'DEPENDIA': 1,
#  'CALLIDAS': 1,
#  'FALAVAMOS': 2,
#  'QUADROS,': 1,
#  'VIVEREI': 1,
#  'VER:': 1,
#  'AJUSTAM': 1,
#  'DESGRAÇADO,': 1,
#  'FAZENDOLA': 1,
#  'METTIA-SE': 2,
#  'AUSENCIA,': 2,
#  'PASSAREM': 1,
#  'GASTEI': 1,
#  'VELAS;': 1,
#  'POVO': 2,
#  '--ENTÃO,': 4,
#  'VISÕES': 2,
#  'LOUVAR-LHE': 1,
#  'AMBOS.': 4,
#  'FIXARAM-SE': 1,
#  'NEED': 1,
#  'EMBRUSCAR-SE,': 1,
#  'OFFICIAL': 3,
#  'ROSTO': 10,
#  'TOCAR': 2,
#  'DESSES': 3,
#  'DEPRIMIR': 1,
#  'ACCENTUAR': 1,
#  'RINDO;': 2,
#  'BEATA': 1,
#  'DESVANECEU': 1,
#  'PAULO,': 6,
#  'SEMANA,': 3,
#  'VINHAM': 10,
#  'SAEM': 1,
#  'SOUZA...': 1,
#  'TIRAL-OS': 1,
#  'ARRANCANDO': 1,
#  'BONECA.': 1,
#  '--ESTOU.': 1,
#  'ESCURO.': 1,
#  'DEDICATORIA': 1,
#  'EXTRAORDINÁRIO;': 1,
#  'DIRECÇÃO,': 1,
#  'QUANDO;': 1,
#  'SACUDIA-ME': 1,
#  'CALCULADO': 1,
#  'PROMESSA,': 5,
#  'VINCES_,': 1,
#  'ANNOS': 26,
#  'VINTENS': 1,
#  'CONHECESSE,': 1,
#  'TOCARIA': 1,
#  'FRIA': 2,
#  'IDADE': 1,
#  'RETICENCIAS,': 1,
#  'PITANGA.': 1,
#  '--ESTE': 1,
#  'IRMÃS.': 1,
#  'BATEU-ME': 2,
#  'MEUS,': 6,
#  'VIER,': 1,
#  'EXQUISITA;': 1,
#  'ACOSTUMADA': 1,
#  'CONSIDERABLE': 2,
#  'PROPRIO': 17,
#  '--CONHEÇO': 1,
#  'QUAES': 11,
#  'VIU-ME,': 1,
#  'PORTANTO,': 2,
#  'HORTA': 1,
#  'CHACARA': 2,
#  'SANTUARIO.': 1,
#  'DESCONFIASSE.': 1,
#  'ACHEI': 29,
#  'AQUI,': 16,
#  'APERTANDO-SE,': 1,
#  'REGALO': 1,
#  'ALGUMA.': 1,
#  'HISTORIADOR': 1,
#  'DESCOBERTAS': 1,
#  'FOLHEAVA': 1,
#  'SABÃO': 1,
#  'ETERNA': 4,
#  'ROUPA': 3,
#  'DERA,': 2,
#  'VAZIA.': 1,
#  'REPRODUZAM,': 1,
#  'BRINCOS.': 1,
#  'MEIGA,': 1,
#  'CALADO:': 1,
#  'ADORNO': 1,
#  'HA.': 1,
#  'MOSTRE': 2,
#  'VENTO,': 2,
#  'IMPLIED,': 1,
#  'MELANCOLICAMENTE': 1,
#  'COSIDAS.': 1,
#  'ESTACOU': 1,
#  'CONHECERIAM': 1,
#  'INTERESSE.': 1,
#  'VERTIDAS': 1,
#  'CERTOS': 3,
#  'SPECIFIC': 1,
#  'VIRTUOSAS.': 1,
#  'BOLSA.»': 1,
#  'ENCOSTADO': 1,
#  'CHOVIA,': 1,
#  'ABERRAÇÃO': 1,
#  'ENCANTADOS': 1,
#  'TRISTEZAS': 2,
#  'EXPLICAÇÃO.': 2,
#  'CHOOSE': 1,
#  'VERSOS,': 3,
#  'ISRAELITA.': 1,
#  'CAPITÚ.»': 1,
#  'AMIGA.': 2,
#  'ENFEIXAVA': 1,
#  'ESCOBAR,': 24,
#  'OUTRAS,': 5,
#  'ALUMIOU': 1,
#  'LOUVAVA': 1,
#  'PEDINDO-ME': 1,
#  'PARAVAM,': 1,
#  'PÉS,': 6,
#  'PEGAR': 7,
#  'HUMANA,': 1,
#  'AURORA,': 2,
#  'DISPOSTA,': 1,
#  'ESCUTA,': 1,
#  'SEGUNDOS;': 1,
#  'EVANGELHO': 1,
#  'OFFICIO...': 1,
#  'OLHA,': 2,
#  'OLHAVA': 9,
#  'RETIRAR': 1,
#  '--VERDADE': 1,
#  'OBEDECESSE': 2,
#  'LIBRETTO': 2,
#  'QUEIXAS;': 1,
#  'ELLES': 32,
#  'ACHADO...': 1,
#  'VENDENDO,': 1,
#  'ULTIMA,': 3,
#  'ALUGARA': 1,
#  'CONSUMISSE': 1,
#  'FIZER': 1,
#  'CARDEAL': 1,
#  'METTIDIÇO': 1,
#  'GOSTO!': 1,
#  '«JOVEN': 1,
#  'ALGARISMOS,': 1,
#  'CABELLO,': 1,
#  'XIX': 2,
#  'SÃO.': 1,
#  'NISSO,': 1,
#  'MOLESTIA': 1,
#  'LEVAVAM': 1,
#  'PEREMPTORIO,': 1,
#  'ABATIDO': 1,
#  'HART': 1,
#  'AGARREI-ME': 3,
#  'DONO.': 1,
#  'TACITO': 1,
#  'PEGADO': 2,
#  'REIS.': 1,
#  'REGRESSAVA': 1,
#  'REPETI-AS:': 1,
#  '«SE': 3,
#  'APONTOU': 1,
#  'SUSPIRO': 1,
#  'INACCURATE': 1,
#  'FIZEMOS,': 1,
#  'PURA!': 4,
#  'FOI-SE': 1,
#  'ATTENÇÕES': 1,
#  'HAVER.': 1,
#  'DEPOIS;': 6,
#  'ESCRIPTAS.': 1,
#  'INSINUOU': 2,
#  'VALEU;': 1,
#  'VENDO-ME': 3,
#  'COMMENTANDO': 1,
#  'MILHARES': 2,
#  'GLOTÃO;': 1,
#  'RESISTIA': 1,
#  'RIJO.': 1,
#  'CHEGA': 2,
#  'ESPANTADA:': 1,
#  'CHITA,': 3,
#  '--AH!': 3,
#  'EXPEND': 1,
#  'SEGUINTE,': 10,
#  'ARITHMETICAS': 4,
#  'CAMPANHAS,': 2,
#  'DESTES': 5,
#  'ASSIM!': 2,
#  'NEGOCIOS,': 1,
#  'LEIS,': 2,
#  '--FIQUE': 1,
#  'ACHA,': 1,
#  'TRATEI': 2,
#  'OLHAVAMOS': 1,
#  'POETICA': 1,
#  'LEVEI-O': 1,
#  'SABE...': 1,
#  'TODOS?': 1,
#  'RECEBER': 4,
#  'MERECE,': 1,
#  'ACABADO.': 1,
#  'DESCONTAI-ME': 1,
#  'MANHÃS': 4,
#  'JORNALISTA,': 1,
#  'SACRIFICIO.': 1,
#  'RETALHOS...': 1,
#  'ELLAS.': 1,
#  'NERO,': 1,
#  'GURGEL.': 2,
#  'PROMPTIDÃO': 1,
#  '1857,': 1,
#  'DERRADEIROS': 1,
#  'LEVADO': 2,
#  'VONTADES,': 1,
#  'ATREVO': 1,
#  'ADULAÇÃO.': 1,
#  'MUDAVAM.': 1,
#  'VIEWING,': 1,
#  'APOSTOLICO': 1,
#  'BRAÇOS,': 4,
#  'PISTON!': 2,
#  'RECOMMENDASSE:': 1,
#  'LEVANTAR': 2,
#  'MIM:': 4,
#  'ONDE': 40,
#  'GLORIA?': 1,
#  'QUER...»': 1,
#  '--TOMA': 1,
#  'SAIRAM': 5,
#  'PEÇO,': 1,
#  'SABEMOS': 1,
#  'ATAQUE': 1,
#  'ANDE,': 3,
#  'BLASPHEMIAS,': 1,
#  'EXPRIME': 1,
#  'PRINCIPIO;': 1,
#  'AMANHÃ': 3,
#  'MELANCOLIA': 1,
#  'EXPANSÕES': 1,
#  'LEGADO;': 1,
#  'DIZENDO...': 1,
#  'ESPERAR,': 4,
#  'KEEPING': 2,
#  'INCLINAÇÃO': 1,
#  '_ZERO_': 1,
#  'VISINHA': 1,
#  'INTERROGAR,': 1,
#  'ORGULHO': 2,
#  'PROPORÇÃO': 1,
#  'MONTAR,': 1,
#  'ASSISTIA': 2,
#  'ESCAPAVAM': 1,
#  'AGRADASSEM': 1,
#  'BONITOS': 1,
#  'INTERVALLO': 1,
#  'COMPLETA-SE': 1,
#  'IMPLICANCIA.': 1,
#  'MORTA': 2,
#  'OUSAVA': 1,
#  'CHEGANDO.': 1,
#  'INQUIETA:': 1,
#  'NOVO,': 11,
#  'CARNE': 2,
#  'ORAVA.': 1,
#  'GOSTARAM': 1,
#  'NOITES;': 1,
#  'BOAS.': 1,
#  'SEI,': 4,
#  'BRANCO;': 1,
#  'FRESCO;': 1,
#  'AMBOS;': 1,
#  'PASSEI': 4,
#  '«ESTA': 1,
#  'FELIZ': 2,
#  'LENTES': 1,
#  'ESSES,': 1,
#  'IMPERATIVO': 1,
#  'BIBLIA.': 1,
#  'CONDEMNADOS': 1,
#  'ANNOS)': 1,
#  'É;': 2,
#  'DISCOVER': 1,
#  'ARREDONDAVAM-SE': 1,
#  'RECEBEU-ME': 1,
#  'JOGO.': 1,
#  'PEGASSE.': 1,
#  'ALGUEM...': 1,
#  'VIGESIMO': 1,
#  'FALOU,': 1,
#  'FALAVA-ME,': 1,
#  'HOMEM': 43,
#  'SUPPÕE': 2,
#  'FAÇA': 9,
#  'OITO': 4,
#  'AVIGORAVAM-SE': 1,
#  'ARRANJADO.': 1,
#  'SUPPONDE': 1,
#  'DISSO': 6,
#  'COPO': 2,
#  'IRÁ': 6,
#  'AR': 17,
#  'DIVIDIR': 2,
#  'GORDO': 1,
#  'ENCHIA-O': 1,
#  'DISPONÍVEL,': 1,
#  'SEGREDOU': 1,
#  'ESTENDERAM': 1,
#  'LETTRA.': 1,
#  'SAUDAÇÕES': 1,
#  'ZANGADO.': 1,
#  'DEIXARA': 1,
#  'FEIOS,': 2,
#  'QUERIA.': 1,
#  'FACILMENTE': 3,
#  'DESCOBRIR': 3,
#  'QUE?': 8,
#  'ENDIREITANDO': 1,
#  'NÓS.': 6,
#  'ACABAR': 18,
#  'IAM-SE': 2,
#  'MUITO;': 5,
#  'PRESTAVAS': 1,
#  'BRANCAS': 1,
#  'PERALTA;': 1,
#  'ACCEPTED': 1,
#  'SUPPUNHA': 1,
#  'MODIFICATION,': 1,
#  'CONCERTAL-A': 1,
#  'PART': 4,
#  'CINCOENTA.': 1,
#  'PROOFREAD': 1,
#  'ESPECIE.': 1,
#  'BISPO»,': 1,
#  'COVA,': 1,
#  'TAL': 75,
#  'PRESUMO,': 1,
#  'BOTICA.': 1,
#  'MULTIPLICAVA': 1,
#  'OBTAIN': 3,
#  'QUEDA,': 1,
#  'VERSION,ALSO': 2,
#  'CONTENTAMENTO': 1,
#  'BASTAR;': 1,
#  'PÓ,': 1,
#  'LOGO,': 16,
#  'BELLAS,': 4,
#  'VALER,': 1,
#  'PEDIU-ME': 10,
#  'PULO,': 1,
#  'PRÉGÃO': 5,
#  'ANDAR': 16,
#  'ACALCANHADOS...': 1,
#  '--MAS': 22,
#  'PASSARINHOS': 1,
#  'MATAR,': 2,
#  'QUASI.': 1,
#  'AGREEMENT': 9,
#  'TRABALHAVAM': 1,
#  'ELOGIA': 1,
#  'APHORISMOS': 1,
#  'EXCELLENTISSIMA': 1,
#  'MENTIRA,': 1,
#  'ENROSCAVAM-SE': 1,
#  'CHEGÁMOS,': 1,
#  '--QUASI': 1,
#  'JUSTAMENTE': 9,
#  'AGRADECIDOS.': 1,
#  'PADRE._': 1,
#  'SI...': 1,
#  'ESTENDEU-NOS': 1,
#  'ALLOW': 1,
#  'VIUVOS.': 1,
#  'MATERIAS': 4,
#  'VISÃO': 1,
#  'PAGINAS;': 1,
#  'VINHO': 2,
#  'IDES': 1,
#  '1.E.4.': 1,
#  'VESTIDO.': 1,
#  'DEZENOVE': 1,
#  'CIGARRA': 1,
#  'CÁ!': 1,
#  'CONSTRUCÇÕES': 1,
#  'COMMIGO;': 6,
#  'FIL-O': 1,
#  'APPETECIVEL,': 1,
#  'POUPANDO': 1,
#  'TECTO,': 2,
#  'TRONCO': 1,
#  'DELLE;': 2,
#  'SÃO?»': 1,
#  'INVEJAS,': 1,
#  'PROMETTENDO,': 1,
#  'EXCLUSIVAMENTE': 2,
#  'SEGUIU-SE': 2,
#  'BONDADE.': 1,
#  'AFFLIGIA,': 1,
#  'SECURE': 1,
#  'DESINENCIA': 1,
#  'PURGATORIO.': 1,
#  'PENTEASTES': 1,
#  'COMMENTARIO:': 1,
#  'DAQUI': 13,
#  'APERTADA': 2,
#  'DEPOIS...': 4,
#  'CONVERSÁMOS': 1,
#  'DEIXASSE,': 1,
#  'ENTRO,': 1,
#  ...}

# %%
with open('../../Dados/DomCasmurroMachadoAssis.txt', 'r', encoding='utf-8') as f:
    texto = f.read()

# %%
stringao = [r.strip(string.pontuation)] for r in stringao
